# %% [markdown]
# # Introduction — the shear channel
#
# So far every result has rested on one object: the first-order (scalar:  $\delta E^{(v)}$, not a slope: $dE/dk$) energy shift a valley feels under strain, i.e., how far valley $v$ moves up or down when the crystal is deformed. Herring and Vogt (1956), that came out of the Hamiltonian perturbation, wrote it as:
#
# $$ H_{\mathrm{HV}}^{(v)} = \delta E^{(v)} = \Xi_d\,\mathrm{Tr}(\varepsilon) + \Xi_u\,\hat{m}^{(v)\mathsf{T}}\varepsilon\,\hat{m}^{(v)}$$
#
# and the two terms carried the cases we already handled: the trace $\mathrm{Tr}(\varepsilon)$ is the hydrostatic channel (all valleys shift together, the gap moves, carrier density changes), and the sandwich $\hat m^{\mathsf T}\varepsilon\hat m$ is the uniaxial channel (valleys along different axes shift by different amounts, they repopulate, and $\pi_{11}, \pi_{12}$ come out).
#
# Why exactly two terms, and not more, has a clean geometrical reason. The energy shift is a scalar — one number pinned to a valley — so it cannot change when we apply a symmetry operation that leaves that valley untouched. Take the $z$-valley, the cigar along $[001]$: it is unchanged by a $90^\circ$ rotation about $z$. Under that rotation $\varepsilon_{xy}\to-\varepsilon_{xy}$ and $(\varepsilon_{xx}-\varepsilon_{yy})\to-(\varepsilon_{xx}-\varepsilon_{yy})$ — they flip sign, but $\delta E$ cannot, because it is the same valley. So their coefficients must be zero. The only combinations that survive the rotation unchanged are $\varepsilon_{zz}$ and $\varepsilon_{xx}+\varepsilon_{yy}$: two of them, hence two deformation potentials, and the Herring–Vogt form is *complete* at first order rather than a lucky guess. This already contains the punchline — $\varepsilon_{xy}$, the trigonal-shear component, is one of the sign-flipping combinations, so it contributes **nothing** to the energy of the $z$-valley, and the same holds for all six. See the proof in the next cell.
#
#
#
#
# *(The 'sandwich' shape itself is just bookkeeping: to turn a rank-2 tensor like $\varepsilon$ into a scalar you contract it from both sides, hence $\hat m^{\mathsf T}\varepsilon\hat m$.)*
#
# We have also seen how strain reshapes the crystal's symmetry. Silicon is space group $227$, $Fd\bar 3m$:
#
# ```
# F  = face-centred lattice           → fcc
# d  = diamond glide                  → the nonsymmorphic ingredient
# 3̄  = 3-fold + inversion axis        → carries the inversion centre
# m  = mirror
# ```
#
# with the 48 operations of the point group $O_h$:
#
# $$E,\ 8C_3,\ 3C_2,\ 6C_2,\ 6C_4,\ i,\ 8S_6,\ 3\sigma_h,\ 6\sigma_d,\ 6S_4.$$
#
# A strain can only *remove* operations — the surviving group is the subset that still maps the deformed crystal onto itself,
#
# $$G(\varepsilon)=\{\,g\in O_h : g\,\varepsilon\,g^{\mathsf T}=\varepsilon\,\}.$$
#
# And because the two ends $\pm\mathbf k$ of each cigar are locked together by time reversal, we really only track three valley-pairs, one along each of $x,y,z$. A splitting is allowed only if some surviving operation fails to shuffle all three into one another:
#
# - **unstrained** — $O_h$ (48). The $C_4$'s about the cube axes send $x\to y\to z$, tying all three pairs together → forced degenerate, six equally filled cigars.
# - **uniaxial [100]** — $O_h\to D_{4h}$ (16). The strain keeps a $4$-fold axis but kills the rotations that sent the strain axis into the other two. Two families remain — the axial pair and the four transverse valleys — nothing forces them equal → $2+4$ split → repopulation → $\pi_{11},\pi_{12}$.
# - **trigonal shear** — $O_h\to D_{3d}$ (12). The surviving rotation is the $3$-fold about the body diagonal $[111]$, and it cycles $x\to y\to z\to x$. That *single* operation ties all three pairs into **one** family → forced to identical energy → identical occupation → no repopulation → $\pi_{44}^{\text{(repop)}}=0$. One rotation settles it; we never need the other eleven.
#
# The twelve operations of $D_{3d}$, spelled out — $E,\ 2C_3,\ 3C_2,\ i,\ 2S_6,\ 3\sigma_d$:
#
# - $2C_3$: rotations by $\pm120^\circ$ about $[111]$ (the one doing the work above),
# - $3C_2$: $180^\circ$ about the three $\langle1\bar10\rangle$ axes lying perpendicular to $[111]$,
# - $i$: inversion, sitting at the bond midpoint,
# - $2S_6$: $\pm60^\circ$ about $[111]$ then reflection in the plane $\perp[111]$,
# - $3\sigma_d$: reflections in the three $\{110\}$ planes that *contain* $[111]$.
#
#
# Group theory tells us the six valleys stay degenerate, but not what the shear actually *does* to them. So put the shear straight into the sandwich and ask what a cigar pointing in a general direction $\hat n$ would feel. Trigonal shear means all off-diagonals equal, diagonals zero, $\varepsilon_{xy}=\varepsilon_{yz}=\varepsilon_{zx}=\varepsilon$:
#
# $$\hat n^{\mathsf T}\varepsilon\,\hat n = 2\varepsilon\,(n_xn_y+n_yn_z+n_zn_x)=\varepsilon\,(3\cos^2\theta-1),$$
#
# where $\theta$ is the angle between $\hat n$ and $[111]$ (using $n_x+n_y+n_z=\sqrt3\cos\theta$). So the shear's energy-shift field is a single lobe about the body diagonal: it lifts a cigar pointing near $[111]$ by up to $+2\varepsilon\Xi_u$, pushes one lying in the $(111)$ plane down by $-\varepsilon\Xi_u$, and gives **exactly zero** on the cone where $3\cos^2\theta=1$, i.e.
#
# $$\theta_0=\arccos\tfrac{1}{\sqrt3}=54.74^\circ.$$
#
# And the whole thing in one line: **the cube axes make exactly $54.74^\circ$ with the body diagonal.** Every one of the six $\Delta$-valleys sits *on the null cone*. The shear does not fail to reach them — it reaches all six with identical weight, and the weight is zero, because the stretch it wants to give along $[111]$ and the squeeze in the $(111)$ plane cancel at that magic angle. That is the geometric answer to whether there is a shear effect: there *is* a real one on generic directions — an up/down lobe about $[111]$ — but the six places we care about all lie exactly where it vanishes.
#
# It is tempting to read $\pi_{44}=0$ as a symmetry *prohibition*. It is not. Under $D_{3d}$ the conductivity is allowed to be uniaxial about $[111]$, and written back in cube axes that already carries a nonzero $\sigma_{xy}$ — so a finite $\pi_{44}$ is symmetry-*allowed* (that is exactly why the cubic tensor needs three numbers $\pi_{11},\pi_{12},\pi_{44}$, not two). What our theorem actually kills is narrower: the **repopulation** mechanism — the one that produced $\pi_{11},\pi_{12}$ — is switched off, because the six valleys never split. And that rests on three assumptions:
#
# 1. rigid bands (energies shift, shapes fixed),
# 2. strain-independent valley masses,
# 3. a single constant $\tau$.
#
# With all three, $\pi_{44}=0$. Note carefully what this rules out and what it doesn't: a fancier Boltzmann solver fed the *same* rigid bands returns the same zero — the extra physics a Monte-Carlo BTE adds lives in the collision integral, but the only strain information we handed it sits in valley energies that did not move. So a better *solver* cannot revive $\pi_{44}$; new *input* can. Drop assumption 2 or 3 and it comes back — and experiment says it does: n-Si has $\pi_{44}\approx-13.6$ against $\pi_{11}\approx-102$ (in $10^{-11}\,\text{Pa}^{-1}$). Small, but not zero, and that survivor is the subject of the rest.
#
# Loosening the assumptions one at a time turns up two doors, and one is already open to us.
#
# The **mass door** (drop assumption 2) is reachable with the machinery we already have. Symmetry fixed the valley *energies* equal; it said nothing about their *shapes*. Under $\varepsilon_{xy}$ the $z$-valley loses the $4$-fold symmetry that had forced its two transverse masses equal and its cross-term $m_{xy}$ to vanish, so the transverse ellipse is now free to go lopsided, with axes rotated onto $[110]$ and $[1\bar10]$. And $m_{xy}$ must be *odd* in $\varepsilon_{xy}$ (flipping the shear swaps $[110]\leftrightarrow[1\bar10]$), so it should turn on **linearly** — a first-order distortion. Since $\sigma=\sum_v n_v e^2\tau\,(M^{(v)})^{-1}$, a tilted mass tensor feeds $\sigma_{xy}$ directly, even with all six occupations equal and $\tau$ fixed. This is the physics behind the $[110]$ mobility boost in strained nMOS (Sun, Thompson & Nishida, already on the shelf). Crucially, this door opens with VASP alone: impose a finite $\varepsilon_{xy}$, compute the bands, fit the mass tensor at the valley minima, and read off whether $m_{xy}$ really turns on linearly and how large it is. No EPW.
#
# Worth flagging why it is subtle: $\varepsilon_{xy}$ splits the degeneracy the $z$-pair carries at $X$, and the valley minimum — sitting only ~15% of the way back from $X$ toward $\Gamma$ — feels a *small* energy denominator. The *energy* of the minimum only drops at **second** order in $\varepsilon$ (consistent with our linear null), while the *shape* responds at first order and can be strong and nonlinear. Which of the energy-null and the mass-signal dominates at each order is precisely what the mass fit will tell us.
#
# The **scattering door** (drop assumption 3) is the one that genuinely needs EPW. Even with rigid bands and fixed masses, a strain- and valley-dependent $\tau(\varepsilon)$ produces $\pi_{44}$; it lives entirely in the electron–phonon coupling $g(\mathbf k,\mathbf q,\varepsilon)$ and is invisible to any constant-$\tau$ treatment. This is the beyond-RTA stretch goal — and it is the *only* part of $\pi_{44}$ that actually requires EPW. So the earlier framing, "the whole $\pi_{44}$ channel is gated behind EPW," was too strict: one of its two sources is a band calculation we can run now.
#
# One crystal note, since shear is where it bites: a Si atom's site symmetry is only $T_d$, not the full $O_h$ — the inversion centre sits at the bond midpoint, between the two sublattices, not on an atom. Shear is the one channel that slides the two sublattices past each other, so the internal (Kleinman) displacement rides along with the macroscopic strain and must be *relaxed*, not frozen, when we compute the shear bands.
#
# The sharpest way to show this channel-decomposition is real, and not an artefact of one material, is to run the same shear on Ge, whose conduction valleys sit at the $L$ points along the $\langle111\rangle$ diagonals. Into the sandwich again: the valley along $[111]$ points straight up the lobe and shifts by $+2\varepsilon\Xi_u$, while the other three lie at $\arccos(-\tfrac13)=70.5^\circ$ from it and each shift by $-\tfrac23\varepsilon\Xi_u$ — a $1+3$ split, traceless as required. Ge's valleys are **off** the null cone, so shear splits them and $\pi_{44}$ is large already at constant $\tau$. And the mirror holds the other way: under $[100]$ strain all four $L$-valleys make the same angle with $[100]$, shift identically, and do *not* split. So:
#
# - **Silicon** — blind to trigonal shear (valleys on the null cone), strong under $[100]$.
# - **Germanium** — blind to $[100]$ (valleys equally tilted to it), strong under trigonal shear.
#
# Smith (1954) says exactly this: n-Ge has $\pi_{11}\approx\pi_{12}\approx-5$ with $\pi_{44}\approx-138$ — the reflection of n-Si. Setting our Si *null* beside the Ge *signal* turns "we computed zero" into a two-sided statement: which strain a crystal responds to is decided by where its valleys sit relative to the strain's geometry. *(Reminder for later: the compliance conversion has to be rebuilt for Ge first — its factors are nowhere near Si's near-unity values.)*
#
# We now go through the first door — the shape of the ellipsoids under $\varepsilon_{xy}$ — with nothing more than band structures and mass fits, and see how far the energy derivatives carry us before we have to open the electron–phonon interaction for the second.

# %% [markdown]
# ### Setup
# The z-valley shift is linear in strain, i.e. a constant symmetric tensor $D^{(z)}$ (the deformation-potential tensor) contracted with $\varepsilon$:
# $$\delta E^{(z)}(\varepsilon) = D^{(z)}:\varepsilon = \sum_{ij}D^{(z)}_{ij}\varepsilon_{ij}.$$
#
# ### Theorem
# If $R$ fixes the z-valley (i.e. $R$ lies in its little group; for Si that is $C_{4v}$, so in particular $R=C_4^z$), then $\delta E^{(z)}$ can depend on only **two** independent combinations of strain,
# $$\delta E^{(z)} = \Xi_d\,\mathrm{Tr}(\varepsilon)+\Xi_u\,\varepsilon_{zz},\qquad \frac{\partial\,\delta E^{(z)}}{\partial\varepsilon_{xy}}=0.$$
#
# ### Proof
# The only physical input: an operation that maps the z-valley onto itself cannot change the z-valley's energy. Such an operation sends the strain $\varepsilon \mapsto R\varepsilon R^{\mathsf T}$, so
# $$
# \begin{align*}
# D^{(z)}:\varepsilon &= D^{(z)}:(R\varepsilon R^{\mathsf T}) &&\forall\,\varepsilon\\
# &= (R^{\mathsf T} D^{(z)} R):\varepsilon &&\forall\,\varepsilon\\
# \Rightarrow\quad R^{\mathsf T} D^{(z)} R &= D^{(z)}.
# \end{align*}
# $$
# Now put in $R=C_4^z$ (the $90^\circ$ turn about $z$). Componentwise, $R^{\mathsf T}D^{(z)}R=D^{(z)}$ reads
# $$
# \begin{align*}
# D_{xx}&=D_{yy},\\
# D_{xy}&=-D_{xy}\;\Rightarrow\;D_{xy}=0,\\
# (D_{xz},D_{yz})&=(-D_{yz},D_{xz})\;\Rightarrow\;D_{xz}=D_{yz}=0,
# \end{align*}
# $$
# so the tensor is forced diagonal with equal transverse entries:
# $$
# D^{(z)}=\begin{pmatrix}d_\perp&0&0\\0&d_\perp&0\\0&0&d_\parallel\end{pmatrix}
# = d_\perp\,\mathbb{1}+(d_\parallel-d_\perp)\,\hat z\hat z^{\mathsf T}.
# $$
# Contract back with $\varepsilon$:
# $$
# \begin{align*}
# \delta E^{(z)}
# &= d_\perp\,(\mathbb{1}:\varepsilon)+(d_\parallel-d_\perp)\,(\hat z^{\mathsf T}\varepsilon\,\hat z)\\
# &= d_\perp\,\mathrm{Tr}(\varepsilon)+(d_\parallel-d_\perp)\,\varepsilon_{zz}\\
# &\equiv \Xi_d\,\mathrm{Tr}(\varepsilon)+\Xi_u\,\hat m^{(z)\mathsf T}\varepsilon\,\hat m^{(z)}\quad\blacksquare
# \end{align*}
# $$
# with $\Xi_d=d_\perp$, $\Xi_u=d_\parallel-d_\perp$, $\hat m^{(z)}=\hat z$. This is the Herring–Vogt form, and it is *complete*: two constants, no room for a third. Because $D^{(z)}$ carries no $xy$ entry, $\varepsilon_{xy}$ drops out — a pure trigonal shear shifts the z-valley by zero at first order. The other five valleys follow by the $O_h$ rotations that permute them onto z.
#
# ### Reading it on the strain side
# The line $D_{xy}=-D_{xy}$ is the crux, and it has a plain meaning: under $C_4^z$ the component $\varepsilon_{xy}$ flips sign (as do $\varepsilon_{xx}-\varepsilon_{yy}$ and, mixing, $\varepsilon_{xz},\varepsilon_{yz}$), whereas $\mathrm{Tr}(\varepsilon)$ and $\varepsilon_{zz}$ are left alone. A quantity forced to equal its own negative is zero, so the z-valley energy can only ride on the two components the rotation leaves untouched. Hydrostatic and $\varepsilon_{zz}$ get through; the shear does not — which is the same statement as $D_{xy}=0$, now read off the strain rather than the tensor.

# %%
from pymatgen.io.vasp import BSVasprun
from pymatgen.electronic_structure.plotter import BSPlotter
import numpy as np
from ase.io import read

import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Load DPT results
import sys
sys.path.append('..')
from results_io import load_result

import numpy as np
from ase.io import read


# VASP
from pymatgen.io.vasp import BSVasprun
from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.core import Spin
from pymatgen.electronic_structure.plotter import BSPlotter
from ase.io import read
import yaml

# system 
import time
import getpass, os, subprocess, glob

# %%
strains = load_result("strains")
print(strains)
isinstance(strains, list)
# Out:
# [-0.01, -0.005, -0.002, 0.0, 0.002, 0.005, 0.01]
# True

# %% [markdown]
# First we can check that the `POSCAR` are written correctly.

# %%
colors  = ['tab:blue', 'tab:orange', 'tab:green']

bss = []
for eps in strains:
    d = f"./eps_{eps:+.4f}"
    bss.append(BSVasprun(f"{d}/vasprun.xml").get_band_structure(
        kpoints_filename=f"{d}/KPOINTS.line", line_mode=True))

plotter = BSPlotter(bss[0])
ax  = plotter.get_plot()
fig = ax.figure

for ln in list(ax.lines):      # <-- the fix (no .clear())
    ln.remove()

for bs, c in zip(bss, colors):
    data = BSPlotter(bs).bs_plot_data(zero_to_efermi=True)
    for dist, ene in zip(data['distances'], data['energy']['1']):
        for band in ene:
            ax.plot(dist, band, color=c, lw=1.0)

# --- force clean tick labels, overriding whatever pymatgen parsed ---
ticks  = plotter.get_ticks()
fixmap = {None: '', 'None': '', 'X_par': r'$X_\parallel$',
          'X_perp': r'$X_\perp$', '\\Gamma': r'$\Gamma$', 'Gamma': r'$\Gamma$'}
seen, xt, xl = set(), [], []
for dpos, lab in zip(ticks['distance'], ticks['label']):
    if dpos in seen:           # de-dupe the Gamma that appears twice (path joint)
        continue
    seen.add(dpos)
    xt.append(dpos)
    xl.append(fixmap.get(lab, lab))
ax.set_xticks(xt)
ax.set_xticklabels(xl)

handles = [Line2D([0],[0], color=c, label=f"ε = {e:+.1%}")
           for e, c in zip(strains, colors)]
ax.legend(handles=handles, loc='upper right')
ax.set_ylim(-4, 5)
fig.savefig("shear_bands.png", dpi=450, bbox_inches='tight')

# %% [markdown]
# ## Phonon dispersion analysis for strained Si
#
# The scattering rate we are ultimately after is
#
# $$\frac{1}{\tau_{n\mathbf{k}}} = \frac{2\pi}{\hbar}\sum_{m,\nu}\int\frac{d\mathbf{q}}{\Omega_{BZ}}\;\big|g_{mn\nu}(\mathbf{k},\mathbf{q})\big|^2\;\Big[(n_{\mathbf{q}\nu}+1-f_{m\mathbf{k+q}})\,\delta(\varepsilon_{n\mathbf{k}}-\varepsilon_{m\mathbf{k+q}}-\hbar\omega_{\mathbf{q}\nu}) + (n_{\mathbf{q}\nu}+f_{m\mathbf{k+q}})\,\delta(\varepsilon_{n\mathbf{k}}-\varepsilon_{m\mathbf{k+q}}+\hbar\omega_{\mathbf{q}\nu})\Big]$$
#
# Most of what goes into it we already have. The band energies $\varepsilon_{n\mathbf{k}}$, $\varepsilon_{m\mathbf{k+q}}$ and the occupations $f_{m\mathbf{k+q}}$ are just the DFT band structure and Fermi level. The phonon frequencies $\omega_{\mathbf{q}\nu}$ — the dispersion this notebook computes — sit in two places: inside the $\delta$-functions, where they enforce energy conservation (the electron's energy change must equal $\pm$ one phonon quantum $\hbar\omega$), and inside the Bose occupation $n_{\mathbf{q}\nu}$, where the two terms are emission ($n+1$) and absorption ($n$). The phonon eigenvectors come in too, but hidden inside $g$.
#
# The one thing we don't have is $g_{mn\nu}(\mathbf{k},\mathbf{q})$, the electron–phonon coupling — how strongly an electron in $(n,\mathbf{k})$ scatters to $(m,\mathbf{k+q})$ by emitting or absorbing phonon $(\mathbf{q},\nu)$. It is the derivative of the electronic potential with respect to the ionic displacement, projected between Bloch states, and it needs the phonon eigenvectors as input — the atoms have to move *somehow*, and the eigenvector says how. That is EPW's job: it takes our phonons and the DFT electrons and builds $g$, and from there the integral gives $1/\tau$, then $\tau \to \mu \to \sigma$.
#
# So the phonon calculation is the vibrational half of the input, feeding both the energy-conservation $\delta$-functions directly and $g$ indirectly through the eigenvectors.
#
# The strain axis is what makes this our problem and not a generic mobility calculation. For $\pi_{44}$ every strain-dependent piece picks up an $\varepsilon$:
#
# $$\frac{1}{\tau_{n\mathbf{k}}(\varepsilon)} \sim \sum \big|g_{mn\nu}(\mathbf{k},\mathbf{q};\boldsymbol{\varepsilon})\big|^2\,\delta(\ldots\pm\hbar\omega_{\mathbf{q}\nu}(\boldsymbol{\varepsilon}))\ldots$$
#
# The theorem said that under constant $\tau$ and rigid bands, trigonal shear doesn't split the valleys, so the band energies in the $\delta$-functions don't move to first order. What survives is the strain-dependence of the coupling $g(\mathbf{k},\mathbf{q};\varepsilon)$ and the phonons $\omega(\mathbf{q};\varepsilon)$ — that is the scattering door, and it needs EPW. But note this is not the whole story: the mass door from the introduction (the shear-induced distortion of the valley ellipsoids) lives in the band curvature, reachable with VASP alone, and it feeds $\sigma$ through $M^{-1}$ rather than through $\tau$.
#
# Here we take the phonon piece, $\omega(\mathbf{q};\varepsilon)$. For each strain we already have the `POSCAR` from the sweep; we run finite-displacement DFT + phonopy on each to get $\omega(\mathbf{q},\varepsilon)$.

# %% [markdown]
# ### Step 1: Setup the connection
# For clarity and documentation purposes, instead of `bash` scripting here we run them directly in `python`.

# %%
PASS = getpass.getpass("Cluster pass")
USER, HOST = "ws2505", "stud2.mpi.univie.ac.at"
REMOTE = "~/Ysafi_runs/disp_curve_sweeps"


def run(cmd, timeout=None):
    '''
    Runs the command line prompt and returns error if one is encountered
    '''
    r = subprocess.run(cmd, shell=True, text=True, capture_output=True, timeout=timeout)
    print(r.stdout)
    if r.returncode != 0: print("STDERR:", r.stderr)
    return r

SSH = f"sshpass -p '{PASS}' ssh -o StrictHostKeyChecking=no -o UserKnownHostsFile=/dev/null {USER}@{HOST}"
SCP = f"sshpass -p '{PASS}' scp -o StrictHostKeyChecking=no -o UserKnownHostsFile=/dev/null"

# %%
def check_connection(timeout=10):
    print("Testing SSH connection...")
    s_time = time.time()
    try: 
        result = run(f"{SSH} 'echo Connected successfully!'", timeout=timeout)
        elapsed_time = time.time() - s_time
        if result.returncode == 0:
            print(f"SSH connection successful! elapsed time {elapsed_time:.2f}")
            return True, None
        else:
            error_msg = f"SSH connection failed! {result.stderr}"
            print(error_msg)
            return False, error_msg
    except subprocess.TimeoutExpired:
        error_msg = f"Connection timeout after {timeout}s"
        print(error_msg)
        return False, error_msg
    except Exception as e:
        error_msg = f'Error: {e}'
        print(error_msg)
        return False, error_msg


success, error = check_connection(5)
assert success, f"Connection failed: {error}"
# Out:
# Testing SSH connection...
# Connected successfully!
#
# SSH connection successful! elapsed time 0.32

# %% [markdown]
# ## Input files for the strained-phonon calculation
#
# ### The two INCARs
#
# The calculation has two stages, so two INCARs:
# - **`INCAR.relax`** — relax the ions inside the strained cell to equilibrium (find the Kleinman internal displacement).
# - **`INCAR.force`** — compute forces on each *displaced* supercell (the finite-difference step that gives force constants).
#
#
# ### Specific tags in `INCAR.relax` (the relaxation)
#
# | tag | value | why |
# |---|---|---|
# | `NSW` | 50 | Max number of ionic relaxation steps. The relaxation must converge *within* this budget. |
# | `IBRION` | 2 | The ionic-relaxation algorithm (conjugate gradient). Moves atoms downhill in energy. |
# | `ISIF` | 2 | **Relax ions only; hold cell fixed.** This is the one that preserves your imposed strain — `ISIF=3` would relax the cell shape and erase the shear. Essential. |
# | `EDIFFG` | −1E-4 | Ionic convergence: stop when all forces are below 1E-4 eV/Å (the minus sign means "force criterion," not energy). Tight, because leftover forces contaminate the phonons. |
#
# ### Specific tags in `INCAR.force` (the finite-displacement forces)
#
# | tag | value | why |
# |---|---|---|
# | `IBRION` | −1 | **Do not move the ions.** Compute forces at the given (displaced) geometry and stop. This is exactly what finite-displacement phonons need: forces *at* the displaced configuration. |
# | `NSW` | 1 | One "step" = a single static force evaluation, no relaxation. |
#
# (No `ISIF`/`EDIFFG` here — we're not relaxing, just reading forces.)
#
# ### KPOINTS files
#
# KPOINTS samples **reciprocal space** (the electronic Brillouin-zone integration).
#
# - **`KPOINTS.prim` (8×8×8)** — for the **primitive cell** (relaxation stage). Small cell, large Brillouin zone, needs a dense k-mesh.
# - **`KPOINTS.sc` (4×4×4)** — for the **2×2×2 supercell** (force stage). The supercell is 8× bigger in real space, its Brillouin zone is 8× *smaller* in reciprocal space, a coarser mesh samples it equivalently. Halving the grid (8 to 4) roughly matches the k-point *density* between the two cells. Using the dense 8×8×8 on the supercell would waste compute; using a coarse grid on the primitive cell would under-converge. **The rule: k-mesh density should be consistent, so bigger cells get coarser grids.**
#
# Both are Γ-centered (`Gamma`), which is optimal for phonons (includes the zone center exactly).
#
# ### `band.conf`
#
# It tells phonopy, *after* the forces are computed:
# - `DIM = 2 2 2` — the supercell size used (so it knows how the force constants tile).
# - `BAND = ...` — the **phonon q-path** (Γ→X→K→Γ→L) in reciprocal coordinates, along which to interpolate and diagonalize D(q).
# - `BAND_LABELS`, `BAND_POINTS` — cosmetic (tick labels) and resolution (101 points per segment).
#
# So KPOINTS.prim/sc sample the *electronic* BZ for VASP; band.conf specifies the *phonon* q-path for phonopy. Two different reciprocal-space samplings for two different purposes.

# %% [markdown]
# ## What the supercell is, and why phonons need one
#
# Silicon is infinite, so we never simulate the whole thing — we take the smallest repeating tile and let it stand in for the crystal. That tile is the **primitive cell**, and for silicon it holds just **2 atoms**: the two sublattices, one atom at the lattice point and one shifted by a quarter of the body diagonal. Copy this tile in all directions and you rebuild the infinite crystal exactly. The rule that makes the code treat the tile as infinite is **PBC** — an atom leaving one face reappears on the opposite one, and forces wrap around the same way.
#
# For the *structure*, 2 atoms is enough, which is why we **relaxed on the primitive cell**. Relaxation only asks "where do the atoms sit at equilibrium," and that answer lives in the smallest tile. No need for anything bigger.
#
# Phonons are where this breaks. A phonon is a wave — atoms in one region displaced one way, atoms further along displaced the other, with some wavelength. But PBC forces every copy of the tile to move *identically*, so a 2-atom box can only represent waves as long as the box itself — the longest wavelengths only. To capture shorter ones, we need a bigger tile where atoms at different spots can move differently. So we glue $2\times2\times2 = 8$ copies of the primitive cell into one block and declare *that* the repeating unit. Eight copies, each carrying 2 atoms, gives $8\times2 = \mathbf{16}$ atoms. That block is the **supercell** — "super" just meaning a larger tile built from copies of the primitive one.
#
# The same size argument shows up a second way in the force calculation. We get force constants by nudging one atom and reading the forces it induces on its neighbours, which reach a few bond lengths. In a tiny box the nudged atom's own periodic image sits right next door, and the two contaminate each other. The supercell puts enough distance between an atom and its images that the force constants **decay to zero before they wrap around** — so the box has to be big enough to contain the coupling, not make it stronger, just let it die out cleanly inside one tile.
#
# In the pipeline this is the *only* place we build a supercell explicitly:
#
# ```
# phonopy -d --dim 2 2 2 -c POSCAR.relaxed
# ```
#
# This does two things — it writes `SPOSCAR`, the undisplaced 16-atom supercell, and it generates the displaced cells `POSCAR-00x`, each being SPOSCAR with one symmetry-inequivalent atom nudged. For silicon the symmetry is high enough that this is a **single** displacement, `POSCAR-001`. VASP then runs a static force evaluation on each displaced cell, and `phonopy -f` reads the forces back into `FORCE_SETS`.
#
# Two things that are *not* the supercell and shouldn't be confused with it: `KPOINTS 444` is the sampling of the **electronic** Brillouin zone (k for electrons), a convergence knob unrelated to phonon wavevectors — and since the supercell is 8× larger in real space, its BZ is 8× smaller, so a coarser k-mesh suffices anyway. And `CONTCAR` is VASP's *output* (the relaxed structure) — phonopy never touches it directly; we rename it to `POSCAR.relaxed` and feed that in.
#
# So the whole flow, in one line:
#
# $$\text{relax (2-atom cell)} \to \text{CONTCAR} \xrightarrow{\text{rename}} \text{POSCAR.relaxed} \xrightarrow{\text{phonopy -d}} \text{SPOSCAR} + \text{POSCAR-001} \xrightarrow{\text{VASP}} \text{forces} \xrightarrow{\text{phonopy -f}} \Phi$$
#
# Small cell for the structure, big cell for the phonons — that split is the whole idea.

# %%
strs = ['-0.0020', '-0.0050', '-0.0100', '+0.0000', '+0.0020', '+0.0050', '+0.0100']
poscar_d = "./eps"
output_d = "./eps_phonon"
RESET_DIR = False

# consistent DFT 
INCAR_scf = """ISTART=0
ICHARG=2
ENCUT=320
ISMEAR=0
SIGMA=0.05
ISYM=0
EDIFF=1E-8
EDIFFG=-1E-4
NSW=50
IBRION=2
ISIF=2
GGA=PE
LREAL=.FALSE.
"""

# Force constant 
INCAR_force = """ISTART=0
ICHARG=2
ENCUT=320
ISMEAR=0
SIGMA=0.05
ISYM=0
EDIFF=1E-8
IBRION=-1
NSW=1
GGA=PE
LREAL=.FALSE.
"""

KPOINTS_PRIM = "auto\n0\nGamma\n8 8 8\n0 0 0\n"    # primitive cell (relax)
KPOINTS_SC   = "auto\n0\nGamma\n4 4 4\n0 0 0\n"    # 2x2x2 supercell (forces) --> eases compute


# phonopy band path: Gamma-X-K-Gamma-L
BAND_CONF = """ATOM_NAME = Si
DIM = 2 2 2
BAND = 0.0 0.0 0.0  0.5 0.0 0.5  0.375 0.375 0.75  0.0 0.0 0.0  0.5 0.5 0.5
BAND_LABELS = \\Gamma X K \\Gamma L
BAND_POINTS = 101
"""


# Files allocations
for e in strs:
    if RESET_DIR:
        for f in glob.glob(f'{output_d}/eps_{e}/*'):
            os.remove(f)

    os.makedirs(f'{output_d}/eps_{e}', exist_ok=True)
    
    # read source POSCAR
    content = open(f'{poscar_d}_{e}/POSCAR').read()
    content2 = open(f'{poscar_d}_{e}/POTCAR').read()
    # Copying existing POSCARs to each directory
    open(f'{output_d}/eps_{e}/POSCAR','w').write(content)
    open(f'{output_d}/eps_{e}/POTCAR','w').write(content2)
    open(f'{output_d}/eps_{e}/INCAR.relax','w').write(INCAR_scf)
    open(f'{output_d}/eps_{e}/INCAR.force','w').write(INCAR_force)
    open(f'{output_d}/eps_{e}/KPOINTS.prim','w').write(KPOINTS_PRIM)
    open(f'{output_d}/eps_{e}/KPOINTS.sc','w').write(KPOINTS_SC)
    open(f'{output_d}/eps_{e}/band.conf','w').write(BAND_CONF)

# %% [markdown]
# ##  Step 1:  Relaxation
# The bellow cell runs VASP and relaxes the geometry and copies it into POSCAR.relax. This cell means convergence of `Potential energy` and the forces should be driven to zero.

# %%
#strs = ['-0.0050', '+0.0050' , '+0.0020'] 

# the input files 
files = ['POSCAR', 'POTCAR', 'INCAR.relax', 'INCAR.force', 
         'KPOINTS.prim', 'KPOINTS.sc', 'band.conf']


#run(f"{SSH} 'rm -rf {REMOTE}/eps_*'")     # clear all stale, ONCE, before uploading
# upload the input dirs
for e in strs:
    cmd = (
    f"{SCP} "
    + " ".join(f"{output_d}/eps_{e}/{f}" for f in files)
    + f" {USER}@{HOST}:{REMOTE}/eps_{e}/"
    )
    run(cmd)
    run(f"{SSH} 'mkdir -p {REMOTE}/eps_{e}'")
    
st1 = """source /etc/profile.d/modules.sh 2>/dev/null || true
module load intel-oneapi-mkl


for d in eps_*/; do
    ( cd "$d" || exit
      cp INCAR.relax INCAR
      cp KPOINTS.prim KPOINTS
      echo "=== $d relaxing ==="
      vasp > log.relax 2>&1
      cp CONTCAR POSCAR.relaxed            # save relaxed cell for the phonon stage
      grep -q "reached required accuracy" OUTCAR && echo "  OK" || echo "  NOT converged"
    )
done
"""
# The sweeps are already done in script
open(f'{output_d}/s1.sh', 'w').write(st1)
run(f"{SCP} {output_d}/s1.sh {USER}@{HOST}:{REMOTE}/")
run(f"{SSH} 'cd {REMOTE} && bash --login s1.sh'")
# Out:
# === eps_+0.0020/ relaxing ===
#   OK
# === eps_+0.0050/ relaxing ===
#   OK
# === eps_-0.0050/ relaxing ===
#   OK
# CompletedProcess(args="sshpass -p 'vasp26' ssh -o StrictHostKeyChecking=no -o UserKnownHostsFile=/dev/null ws2505@stud2.mpi.univie.ac.at 'cd ~/Ysafi_runs/disp_curve_sweeps && bash --login s1.sh'", returncode=0, stdout='=== eps_+0.0020/ relaxing ===\n  OK\n=== eps_+0.0050/ relaxing ===\n  OK\n=== eps_-0.0050/ relaxing ===\n  OK\n', stderr="Warning: Permanently added 'stud2.mpi.univie.ac.at' (ED25519) to the list of known hosts.\n/home/ws2505/.bash_profile: line 1: .bashrc: No such file or directory\n")

# %% [markdown]
# The relaxation step above brought us geometrically to a minimum of the potential energy surface, where the linear term in the Taylor expansion vanishes. The first surviving term is then quadratic; truncating there — dropping the higher-order terms that would carry anharmonicity — is the harmonic approximation, and it reduces the problem to fitting the curvature of the well. The following steps compute that curvature, the Hessian $\Phi$, and read the force constants off it.
#
# There are two routes to the Hessian. Finite differences displaces atoms in a supercell and differences the resulting forces — this is our production method, validated against the known unstrained Si dispersion in `vibrational_props.ipynb`. DFPT (VASP's `IBRION=8`) instead gets the same $\Phi$ analytically, as the first-order perturbative response of the density to an ionic displacement. Here we run DFPT on the unstrained crystal as a cross-check: its job is to reproduce, to within finite-difference error, the dispersion we already trust — so the choice of method isn't a loose end when we scale to the strained cells, where finite differences (cheaper on this single-core machine, and the route to the forces we need for $g(\mathbf q,\varepsilon)$) does the production work.

# %%
# DFPT run (waitng for a better cluster)


'''st2 = """source /etc/profile.d/modules.sh 2>/dev/null || true
module load intel-oneapi-mkl

for d in eps_*/; do
    (
    cd "$d" || exit
    cp INCAR.force INCAR
    cp KPOINTS.sc KPOINTS

    phonopy -d --dim 2 2 2 -c POSCAR.relaxed
    cp SPOSCAR POSCAR
    echo "=== $d calculating forces ==="
    vasp > log.force 2>&1

    )
done

grep -q "General timing" OUTCAR && echo "  VASP OK" || echo "VASP FAILED"
"""

open(f'{output_d}/s2.sh', 'w').write(st2)
run(f"{SCP} {output_d}/s2.sh {USER}@{HOST}:{REMOTE}/")
run(f"{SSH} 'cd {REMOTE} && bash --login s2.sh'")'''
# Out:
# 'st2 = """source /etc/profile.d/modules.sh 2>/dev/null || true\nmodule load intel-oneapi-mkl\n\nfor d in eps_*/; do\n    (\n    cd "$d" || exit\n    cp INCAR.force INCAR\n    cp KPOINTS.sc KPOINTS\n\n    phonopy -d --dim 2 2 2 -c POSCAR.relaxed\n    cp SPOSCAR POSCAR\n    echo "=== $d calculating forces ==="\n    vasp > log.force 2>&1\n\n    )\ndone\n\ngrep -q "General timing" OUTCAR && echo "  VASP OK" || echo "VASP FAILED"\n"""\n\nopen(f\'{output_d}/s2.sh\', \'w\').write(st2)\nrun(f"{SCP} {output_d}/s2.sh {USER}@{HOST}:{REMOTE}/")\nrun(f"{SSH} \'cd {REMOTE} && bash --login s2.sh\'")'

# %% [markdown]
# Back to finite differences for the sweep — DFPT is parked until we have a real cluster. `IBRION=-1` now, so each displaced cell gets one static force evaluation.
#
#
# > In plain language, the cell below runs `phonopy -d --dim 2 2 2 -c POSCAR.relaxed`, which builds the $2\times2\times2$ supercell — 8 copies of the primitive cell, so 16 atoms — and then generates the symmetry-inequivalent displaced cells `POSCAR-00i`, each with one atom nudged off its site. For unstrained Si the symmetry is high enough that this is a single displacement; a sheared cell breaks symmetry and gives more. We then run `VASP` (`IBRION=-1`, static — no relaxation) on each displaced cell to get the forces on the *frozen* geometry. phonopy finite-differences those forces against the displacement to build the force constants, collected into `FORCE_SETS`.
#
# >The displaced atom is held **fixed off-equilibrium** on purpose — the restoring force it feels *is* the measurement.

# %%
st2 = """source /etc/profile.d/modules.sh 2>/dev/null || true
module load intel-oneapi-mkl
export PATH=$HOME/.local/bin:$PATH

echo "=== phonopy version ==="
phonopy --version

for d in eps_*/; do
    (
    cd "$d" || exit
    cp INCAR.force INCAR
    cp KPOINTS.sc KPOINTS

    phonopy -d --dim 2 2 2 -c POSCAR.relaxed
    
    NDISP=$(ls POSCAR-0* 2>/dev/null | wc -l)
    echo "=== displacements found: $NDISP ==="
    [ "$NDISP" -eq 0 ] && { echo "still zero, stopping"; exit 1; }
    ls POSCAR-0* # debugging 

    echo "=== forces ==="
    for f in POSCAR-0*; do
        n=${f#POSCAR-}
        cp "$f" POSCAR
        vasp > log.force-$n 2>&1
        cp vasprun.xml vasprun-$n.xml
        echo "  done: $n"
    done

    echo "=== FORCE_SETS ==="
    phonopy -f vasprun-*.xml
    ls -l FORCE_SETS && echo SUCCESS for eps $d || echo FAILED

    )
done
"""

open(f'{output_d}/s2.sh', 'w').write(st2)
run(f"{SCP} {output_d}/s2.sh {USER}@{HOST}:{REMOTE}/")
run(f"{SSH} 'cd {REMOTE} && bash --login s2.sh'")
# Out:
# === phonopy version ===
#         _
#   _ __ | |__   ___  _ __   ___   _ __  _   _
#  | '_ \| '_ \ / _ \| '_ \ / _ \ | '_ \| | | |
#  | |_) | | | | (_) | | | | (_) || |_) | |_| |
#  | .__/|_| |_|\___/|_| |_|\___(_) .__/ \__, |
#  |_|                            |_|    |___/
#                                        3.5.1
#
# -------------------------[time 2026-08-13 09:33:14]-------------------------
# Compiled with OpenMP support (max 1 threads).
# Python version 3.10.12
# Spglib version 2.7.0
#
# Crystal structure was read from "POSCAR.relaxed".
# Unit of length: angstrom
# Displacements creation mode
#   Systematic displacements
# Settings:
#   Supercell: [2 2 2]
# Spacegroup: R-3m (166)
# Number of symmetry operations in supercell: 96
# Use -v option to watch primitive cell, unit cell, and supercell structures.
#
# Generated number of supercells: 2
# "phonopy_disp.yaml" and supercells have been created.
#
# Summary of calculation was written in "phonopy_disp.yaml".
# ...

# %% [markdown]
# ### Assembly

# %%
st3 = """export PATH=$HOME/.local/bin:$PATH

for d in eps_*/; do

(
    cd "$d" || exit
    phonopy --fc-symmetry -c POSCAR.relaxed band.conf
    phonopy-bandplot --gnuplot band.yaml > band.dat
    echo "=== outputs: ==="
    ls -l band.yaml band.dat
    echo "=== imaginary (THz)? ==="
    awk 'NF==2 && $2<-0.05{c++} END{print "negatives:",c+0}' band.dat
)
done
"""
open(f'{output_d}/s3.sh',"w").write(st3)
run(f"{SCP} {output_d}/s3.sh {USER}@{HOST}:{REMOTE}/")
run(f"{SSH} 'cd {REMOTE} && bash --login s3.sh'")

for e in strs:
    run(f"{SCP} {USER}@{HOST}:{REMOTE}/eps_{e}/band.yaml {output_d}/eps_{e}/")
    run(f"{SCP} {USER}@{HOST}:{REMOTE}/eps_{e}/band.dat {output_d}/eps_{e}/")
    run(f"{SCP} {USER}@{HOST}:{REMOTE}/eps_{e}/CONTCAR {output_d}/eps_{e}/") # for symmetry analysis
    print("fetched")
# Out:
#         _
#   _ __ | |__   ___  _ __   ___   _ __  _   _
#  | '_ \| '_ \ / _ \| '_ \ / _ \ | '_ \| | | |
#  | |_) | | | | (_) | | | | (_) || |_) | |_| |
#  | .__/|_| |_|\___/|_| |_|\___(_) .__/ \__, |
#  |_|                            |_|    |___/
#                                        3.5.1
#
# -------------------------[time 2026-08-13 09:57:43]-------------------------
# Compiled with OpenMP support (max 1 threads).
# Python version 3.10.12
# Spglib version 2.7.0
#
# "band.conf" was read as phonopy configuration file.
# Crystal structure was read from "POSCAR.relaxed".
# Unit of length: angstrom
# Band structure mode
# Settings:
#   Force constants symmetrization: on
#   Supercell: [2 2 2]
# Spacegroup: R-3m (166)
# Number of symmetry operations in supercell: 96
# Use -v option to watch primitive cell, unit cell, and supercell structures.
#
# Displacement-force dataset was read from "FORCE_SETS".
# Max drift of force constants: 0.00000035 (zz) 0.00000035 (yy)
# ...

# %% [markdown]
# ### q-path and interploating Dq along it
# phonopy has $\Phi$; it Fourier-transforms to $D(q)$ and diagonalises at each q along Γ–X–K–Γ–L. We read the frequencies straight out of `band.yaml`.

# %%
# Define different colors and line styles
colors = ['blue', 'red', 'gold', 'green', 'purple', 'orange', 'brown', 'pink', 'cyan', 'magenta']
line_styles = ['--','-.',  ':','-', '--', '-.', ':']

plt.figure(figsize=(7.5,5), dpi=300)

# Create empty list to store legend handles
legend_handles = []

for idx, e in enumerate(strs):
    with open(f"./{output_d}/eps_{e}/band.yaml") as f:
        bs = yaml.safe_load(f)

    dist  = np.array([p["distance"] for p in bs["phonon"]])
    freqs = np.array([[b["frequency"] for b in p["band"]] for p in bs["phonon"]])
    print("q-points:", freqs.shape[0], " branches:", freqs.shape[1])
    print("freq range (THz):", round(float(freqs.min()),2), "to", round(float(freqs.max()),2))
    
    if idx == 0:
        labels = ["Γ", "X", "K", "Γ", "L"]
        seg_ends = [dist[0]]
        

        for i in range(1, len(dist)):
            if dist[i] == dist[i-1]:
                seg_ends.append(dist[i])
        seg_ends.append(dist[-1])
        if len(seg_ends) != len(labels):
            seg_ends = np.linspace(dist.min(), dist.max(), len(labels))
        
        plt.axhline(0, color='gray', lw=0.5)
        for x in seg_ends:
            plt.axvline(x, color='gray', lw=0.4)
        plt.xticks(seg_ends, labels)

    # Plot with different color and line style for each strain
    style = line_styles[idx % len(line_styles)]
    color = colors[idx % len(colors)]
    
    # Plot all branches for this strain
    for b in range(freqs.shape[1]):
        plt.plot(dist, freqs[:,b], color=color, linestyle=style, 
                lw=1.2, alpha=0.8)
    
    # Create a dummy line for the legend (only one per strain)
    # This represents all branches for this strain
    legend_handles.append(plt.Line2D([0], [0], color=color, linestyle=style, 
                                     lw=1.2, alpha=0.8, label=f"ε={e}"))

plt.ylabel("Frequency (THz)")
plt.title(f"Silicon phonon dispersion — different strains")
plt.tight_layout()
# Use the custom legend handles
plt.legend(handles=legend_handles, loc='best')
plt.show()
# Out:
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.44
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.5
# q-points: 404  branches: 6
# freq range (THz): 0.0 to 15.6
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.4
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.42
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.45
# q-points: 404  branches: 6
# freq range (THz): -0.0 to 15.49

# %% [markdown]
# ## Asymmetry analysis
#
# The ±1% plot is tempting to read as "bigger strain, clearer signal." But for shear that's backwards. Because +ε and −ε are mirror images of the same distortion, every quantity is either even or odd in ε — and the *contamination* from the next (opposite-parity) order grows with strain. So a large strain doesn't sharpen the analysis, it mixes in higher-order terms.
#
# We can see this directly in the geometry. If we relax +ε and −ε, the internal (Kleinman) displacement of the sublattices should come out equal and opposite — perfectly odd in ε. Any deviation from that mirror is the higher-order contamination showing up. So we measure how well the ±ε displacements mirror each other, at large strain vs small, and pick the strain range where the mirror holds cleanest. The relevant numbers live in each `CONTCAR`.

# %%
# We load the contcar files of +- strains and compare the supercells displacements and calculate errors on them

def coordinate_extract(e):
    with open(f'{output_d}/eps_{e}/CONTCAR', 'r') as c:
            lines = c.readlines()
    
    # find direct line and extract next 16 lines
    for i, l in enumerate(lines):
        if l.strip() == "Direct":
            # Get 16 lines of coordinates and convert to numpy array
            coords = np.array([list(map(float, lines[i+1+j].strip().split())) 
                              for j in range(16)])
            break
    return coords

def assymetry_analysis(ref_crd, crd1, crd2):
    atom = 5
    # now compare to reference
    # how much each displaced
    eps_pos = crd1[atom] - ref_crd[atom]
    eps_neg = crd2[atom] - ref_crd[atom]

    # wrapping around for PBC handling
    eps_pos = eps_pos - np.round(eps_pos)
    eps_neg = eps_neg - np.round(eps_neg)

    # note: the eps positive is already a negative value
    assymetry = np.abs(eps_neg + eps_pos)/np.abs(eps_neg)
    
    return assymetry

ref_crd = coordinate_extract('+0.0000')

from collections import defaultdict
pairs = defaultdict(dict)
for e in strs:
    mag = abs(float(e))
    sign = '+' if float(e) >= 0 else '-'
    pairs[mag][sign] = e

mags, asyms = [], []
for mag, d in sorted(pairs.items()):
    if mag == 0.0:            # unstrained = reference, no mirror pair
        continue
    if '+' not in d or '-' not in d:   # only one sign present, can't mirror
        continue
    crd_pos = coordinate_extract(d['+'])
    crd_neg = coordinate_extract(d['-'])
    asym = assymetry_analysis(ref_crd, crd_pos, crd_neg)
    print(f"±{mag}: {asym}")
    mags.append(mag)
    asyms.append(asym)

#crd1 = coordinate_extract('+0.0050') 
#crd2 = coordinate_extract('-0.0050')
#
#crd3 = coordinate_extract('+0.0020') 
#crd4 = coordinate_extract('-0.0020')
#
#crd5 = coordinate_extract('+0.0100') 
#crd6 = coordinate_extract('-0.0100')
#
#
#missmatch_eps_small = assymetry_analysis(ref_crd, crd3, crd4)
#missmatch_eps_med = assymetry_analysis(ref_crd, crd1, crd2)
#missmatch_eps_large = assymetry_analysis(ref_crd, crd5, crd6)
plt.plot(mags, asyms, 'o-')
plt.xlabel('|ε|'); plt.ylabel('mirror asymmetry')
plt.title("Assymtery analysis")
# Out:
# ±0.002: [0.02098921 0.02099039 0.02098984]
# ±0.005: [0.05442656 0.05442648 0.05442607]
# ±0.01: [0.1065044  0.10650448 0.10650431]
# Text(0.5, 1.0, 'Assymtery analysis')

# %% [markdown]
# ## Asymmetry analysis — shear as a small-strain measurement
#
# Everything depends on **parity in ε**. Expand any strained quantity about the unstrained cell:
#
# $$Q(\varepsilon) = Q_0 + a\,\varepsilon + b\,\varepsilon^2 + c\,\varepsilon^3 + \dots$$
#
# For a shear, $+\varepsilon$ and $-\varepsilon$ are mirror images of the same distortion — the off-diagonal strain just flips sign, same shear, opposite handedness. The crystal must respond to them as mirrors, so every quantity is forced to be either purely **even** or purely **odd** in ε:
#
# - **even** $(Q(-\varepsilon)=Q(+\varepsilon))$: odd coefficients $a,c,\dots$ vanish, leading term $b\,\varepsilon^2$.
# - **odd** $(Q(-\varepsilon)=-Q(+\varepsilon))$: even coefficients vanish, leading term $a\,\varepsilon$.
#
# Which is which:
#
# - **Phonon frequencies $\omega$ are even.** At ±0.002 the dispersions sit on top of each other, and the Γ optical frequencies land on the *same side* of unstrained (both sheared cells higher). So $\omega(\varepsilon)\approx\omega_0 + b\varepsilon^2$, no linear term — the leading physics is the **curvature** $b$.
# - **The electronic mass cross-term $m_{xy}$ is odd** (predicted, not yet computed): flipping the shear swaps $[110]\leftrightarrow[1\bar10]$, so $m_{xy}\to-m_{xy}$. Leading physics is the **slope** $a$.
#
# To extract a leading coefficient cleanly, the strain must be small enough that the *next* term — always of **opposite parity** — hasn't crept in. For $\omega$ (even) the contaminant is the odd $c\varepsilon^3$; for $m_{xy}$ (odd) it's the even $b\varepsilon^2$. Either way the contamination *grows with strain*, so bigger ε is worse, not better.
#
# The Kleinman displacements confirm this directly. The ±ε sublattice shifts should be equal and opposite (odd). Measuring their mirror-violation, $|d(+\varepsilon)+d(-\varepsilon)|/|d(-\varepsilon)|$:
#
# - at **±1%**: ~11% violation
# - at **±0.2%**: ~2% violation
#
# A 5× drop in strain gives a 5× drop in asymmetry — *linear* in ε, exactly what an odd higher-order contamination must do (relative error $\sim (b/a)\varepsilon$). So the broken mirror at 1% is genuine higher-order physics, not noise, and ±0.2% is the clean regime.
#
# This inverts the other channels. Hydrostatic and uniaxial have a *linear* leading response (deformation potential, valley splitting), so ±1% is a large clean signal — bigger is better. Shear's leading response is one order up (even → $\varepsilon^2$), so large strain just folds in the opposite-parity junk. **Shear is a small-strain measurement by nature** — a methodological consequence of its parity, not a limitation.
#
# The estimators, chosen by parity (both need ±ε):
#
# $$\text{even } (\omega):\quad \frac{d^2\omega}{d\varepsilon^2}\Big|_0 \approx \frac{\omega(+\varepsilon)-2\omega(0)+\omega(-\varepsilon)}{\varepsilon^2}\quad(=2b)$$
#
# $$\text{odd } (m_{xy}):\quad \frac{dm_{xy}}{d\varepsilon}\Big|_0 \approx \frac{m_{xy}(+\varepsilon)-m_{xy}(-\varepsilon)}{2\varepsilon}\quad(=a)$$
#
# The mirror saves me the *large*-strain duplicates (reflect them), but never the small-strain pair — the derivative is built from it.
#
# **TL;DR** — Shear deforms the crystal *mirror-symmetrically* in ε: $+\varepsilon$ and $-\varepsilon$ are the same distortion with opposite handedness. So each quantity is either even or odd in ε. Phonon frequency is **even** — the lattice vibrates the same regardless of which way the shear tilts — so its first-order term vanishes and the leading response is $O(\varepsilon^2)$. (The electronic off-diagonal mass $m_{xy}$, which we compute later in the mass-door step, is predicted **odd**: unstrained cubic symmetry forces $m_{xy}=0$, and shear is what switches it on with a sign that follows the shear.) The catch: for an even quantity the leading contaminant is the *odd* $\varepsilon^3$ term, and it grows with strain — so large ε folds in higher-order junk. We confirmed this on the Kleinman displacement: the ±ε mirror holds to ~2% at ±0.2% but breaks to ~11% at ±1%, scaling linearly with ε as an odd contamination must. Hence derivatives are taken at small strain — ±0.2% is the clean regime.

# %% [markdown]
# **Next:** take the even second-difference of $\omega$ at ±0.002, at the q where the optical splitting is largest (the Γ optical triplet), and tabulate the split vs ε. That curvature is the leading phonon response to shear, extracted in the regime just proven clean.
# With $\Phi$ in hand, the dynamical matrix is its Fourier transform, $D(q)=\sum_R \Phi(R)\,e^{iq\cdot R}$ (mass-weighted). Diagonalising it at each q gives the frequencies $\omega(q)$ as eigenvalues and the polarisation vectors as eigenvectors — the dispersion curve, and the "how the atoms move" that later feeds $g$.

# %% [markdown]
# ## two doors to a non-zero $\pi_{44}$
#
# We have proofed at the beginning of this notebook, that the $\pi_{44} = 0$, under 2 assumptions constant-$\tau$ RTA with rigid valley masses — the repopulation channel is switched off, because trigonal shear doesn't split the six valleys. From here two independent assumptions can revive $\pi_44$ back:
#
# 1. Drop the rigid-mass assumption: Shear distorts the constant energy ellipsoids (cigars), giving the efffective mass tensor an off-diagonal $m_{xy}$; this feeds $\sigma$ directly through $M^{-1}$, with $\tau$ constant and all valleys equally occupied. Reachable with VASP alone — fit the mass tensor at the $\Delta$-valley minimum in the sheared bands. Kanda & Suzuki (PRB 43,6754,1991).
#
# 2. Varying scattering rate (drop constant-$\tau$ assumption): Such scattering rate requires phonons ($\omega_{\mathbf{q}\nu}(\varepsilon)$) and the electron-phonon coupling ($g_{mn\nu}(\mathbf{k},\mathbf{q};\varepsilon)$). Of the two we have computed strain-dependent phonon dispersion the other needs performing `EPW` calculations for computing the **electron-phonon matrix element ($g_{mnv}(k,q; \varepsilon)$)**.
#
# We start by studying the first way, and if time allowed we go to compute the second.

# %% [markdown]
# ## Mass door
#
# The mass door is open if shear gives the valley a nonzero off-diagonal mass $m_{xy}$ (it was zero in the unstrained cubic cell). So we compute $m_{xy}(\varepsilon)$ and check its slope at zero:
#
# $$\frac{dm_{xy}}{d\varepsilon}\Big|_0 \approx \frac{m_{xy}(+\varepsilon)-m_{xy}(-\varepsilon)}{2\varepsilon}.$$
#
# A nonzero $m_{xy}$ with nonzero slope shows the door is open; the oddness ($m_{xy}(-\varepsilon)=-m_{xy}(+\varepsilon)$) confirms it's the predicted linear, symmetry-allowed response.
#
# The effective-mass tensor is the band Hessian at the valley minimum:
#
# $$E(\mathbf{k}) = E_0 + \frac{\hbar^2}{2}\sum_{ij}(k-k_0)_i\,(M^{-1})_{ij}\,(k-k_0)_j,
# \qquad (M^{-1})_{ij} = \frac{1}{\hbar^2}\frac{\partial^2 E}{\partial k_i\,\partial k_j}.$$
#
# For uniaxial we sampled two lines through $k_0$ — parallel and perpendicular — giving the two diagonal curvatures $m_\parallel, m_\perp$ (see `uniaxial.ipynb`). That won't work here: the off-diagonal $\partial^2E/\partial k_x\partial k_y$ is invisible to axis-aligned lines. To resolve the cross-derivative we need a **2D patch** in the plane the shear mixes, with off-axis points around $k_0$, and we fit the full quadratic form — all components of $(M^{-1})_{ij}$ at once.
#
# ### Generating the patch around $k_0$
#
# A small local grid centered on $k_0$, via finite differences. Generation and docs in `k_grid.py`.

# %%
bs  = BSVasprun("eps_+0.0000/mass_val/vasprun.xml").get_band_structure(
           kpoints_filename="eps_+0.0000/mass_val/KPOINTS.grid", line_mode=True)
cbm1 = bs.get_cbm()
bi1  = cbm1["band_index"][Spin.up][0]
E1   = bs.bands[Spin.up][bi1] - cbm1["energy"]

# The energies of the grid points
E_grid = E1.reshape(3,3)

y_mean = np.mean(E_grid[:,-1])
x_mean = np.mean(E_grid[-1,:])
print(y_mean, x_mean)
# Print with labels
print("       -y      y0      +y")
for i, row_label in enumerate(['-x', 'x0', '+x']):
    print(f"{row_label}  {E_grid[i, 0]:.4f}  {E_grid[i, 1]:.4f}  {E_grid[i, 2]:.4f}")

assert np.allclose(E_grid, E_grid.T, atol=1e-0), "Not symm"


#imin1  = int(np.argmin(E1))
#kfrac1 = bs.kpoints[imin1].frac_coords
#kcart1 = bs.structure.lattice.reciprocal_lattice.get_cartesian_coords(kfrac1)
#
#a_lat = np.linalg.norm(read('../Equilibirium_run/outputs/POSCAR').cell[0]) * np.sqrt(2)
#print(f"valley min  fractional : {np.round(kfrac1, 4)}")
#print(f"valley min  Cartesian  : {np.round(kcart1, 4)} A^-1")
#print(f"|k| / (2pi/a)          : {np.linalg.norm(kcart1) / (2*np.pi/a_lat):.3f}   (Si CBM at 0.85)")
#
#plt.figure(figsize=(6, 3.6))
#plt.plot(bs.distance, E1, '.-', ms=4)
#plt.xlabel("k-path distance (1/A)"); plt.ylabel(r"$E - E_{CBM}$ (eV)")
#plt.title("mass_eps0: L leg (left) and T leg (right)")
#plt.grid(alpha=0.3); plt.tight_layout(); plt.show()
# Out:
# 0.05543333333333352 0.04176666666666703
#        -y      y0      +y
# -x  0.0597  0.0101  0.0597
# x0  0.0488  0.0000  0.0488
# +x  0.0578  0.0097  0.0578

# %%
# --- physical constants ---
kB   = 8.617333262e-5     # Boltzmann constant [eV/K]
T    = 300.0              # temperature [K]
HBAR2_OVER_2ME = 3.80998  # hbar^2 / 2 m_e  [eV A^2]

def mass_1d(three_E, h):
    k = np.array([-h, 0.0, h])
    C, b, c = np.polyfit(k, three_E, 2)   # E = C k^2 + b k + c
    return HBAR2_OVER_2ME / C, C, b


Ex = E_grid[:, 1]
Ey = E_grid[1, :]

print(Ex, Ey)
h = 0.05

ml, Cx, bx = mass_1d(Ex, h)
mt, Cy, by = mass_1d(Ey, h)
print("along x (center column):", np.round(Ex,4), " -> m =", round(ml,3), " C =", round(Cx,4), " b =", round(bx,5))
print("along y (center row)   :", np.round(Ey,4), " -> m =", round(mt,3), " C =", round(Cy,4), " b =", round(by,5))

lit = {"m_l": 0.98, "m_t": 0.19}
print(f"\n  m_l/m_e :  DFT = {ml:.3f}   lit = {lit['m_l']}   D = {100*(ml-lit['m_l'])/lit['m_l']:+.1f}%")
print(f"  m_t/m_e :  DFT = {mt:.3f}   lit = {lit['m_t']}   D = {100*(mt-lit['m_t'])/lit['m_t']:+.1f}%")
print(f"  anisotropy m_l/m_t = {ml/mt:.2f}")
# Out:
# [0.0101 0.     0.0097] [0.0488 0.     0.0488]
# along x (center column): [0.0101 0.     0.0097]  -> m = 0.962  C = 3.96  b = -0.004
# along y (center row)   : [0.0488 0.     0.0488]  -> m = 0.195  C = 19.52  b = -0.0
#
#   m_l/m_e :  DFT = 0.962   lit = 0.98   D = -1.8%
#   m_t/m_e :  DFT = 0.195   lit = 0.19   D = +2.7%
#   anisotropy m_l/m_t = 4.93

# %% [markdown]
# ## Mass door — where I stopped
#
# *(updated after the k0 / stencil session)*
#
# **Validation gate: passed.** Unstrained patch → m_l = 0.962, m_t = 0.195, mixed 2nd
# diff = 0.0000. The m_l below lit 0.98 is fully accounted, not error: ~1% PBE (the
# dense-leg fit reads 0.971 = the functional's own m_l) + ~1% stencil order (3-pt central
# diff at ±0.05 vs 11-pt windowed fit at ±0.017 Å⁻¹). Proven by down-sampling the *uni*
# leg to the 3-pt stencil on its own eigenvalues → 0.971 becomes 0.959, reproducing the
# patch with nothing changed but point count. The shear/uni gap was never geometry or k0
# — it's estimator order on a nonparabolic band. **Label: stencil-order artifact.**
#
# **k0 centering: resolved, old worry half-wrong.** argmin was snapping to the nearest of
# 40 line points (~0.005 off the true vertex along x); fixed by fitting the vertex (−b/2C)
# on the X_par leg instead of argmin → b ≈ −0.004. The *residual* x-asymmetry is
# symmetry-allowed and stays: the valley's little group is C4v, whose σv makes E even in
# the transverse direction (why y is machine-clean), but nothing in C4v inverts
# displacements along the axis, so the longitudinal band carries an odd cubic term. It
# cancels identically in the even mass estimator (E₊+E₋−2E₀) and in the mixed difference,
# so it never enters a kept number.
#
# **So the old acceptance test was wrong** — "symmetric paraboloid every direction"
# demanded deleting symmetry-allowed physics. Replace with the two invariant tests, both
# holding:
# - diagonal c₂ *frozen* in h (the quartic bias C+Bh² is even and ε-independent — freeze
#   it, don't chase it),
# - mixed 2nd diff = 0 at ε=0.
#
# **h: understood, not a knob to keep tuning.** ×3 step gives clean 10–30 meV; the ×10
# corner-kinks were neighbouring valleys (correctly diagnosed). Exact h no longer critical:
# the diagonal quartic bias is even in ε → cancels in dm_xy/dε, and the mixed difference
# annihilates the whole Ck²+Bk⁴ longitudinal piece → M is stencil-immune at this order.
# Patch is already fit for purpose for the mass door. Only requirement: h *frozen* across
# the sweep.
#
# ---
#
# **Next: make the k-point generation sweep-flexible, then sweep.**
#
# The ε=0 script is a special case (1D vertex fit along X_par) and only works because
# symmetry pins the minimum onto that line (y≡0). Under [111] shear the minimum drifts
# *off* the high-symmetry line — that drift is physical, part of what shear does to the
# valley — so 1D can't find it. Need one relocation routine, identical at every ε:
#
# 1. SCF per ε → own CHGCAR (no reuse across strains).
# 2. Line-run k0 as the seed.
# 3. 2D Newton on the 3×3 patch: fit in-plane linear coeffs (b_x, b_y) and curvatures
#    (C_x, C_y), step k0 → k0 − ½(b_x/C_x, b_y/C_y), rebuild patch, re-run non-SCF,
#    iterate until both linear terms ≈ 0 (1–2 steps). At ε=0 the y-step is null → reduces
#    to the current script.
# 4. Same frozen h (Å⁻¹) and same fit order at every point → constant bias → cancels in
#    the derivative.
#
# **Deliverable is dm_xy/dε, not m_xy itself.** m_xy is odd in ε for shear → fit m_xy(ε)
# linearly through the small-ε points and read the slope. Stay in the clean window: ±0.2%
# (the ±0.002 points) is the linear regime; by ±1% odd higher-order terms contaminate the
# slope. Use ±0.005 / ±0.010 to *check* the contamination onset, not for the derivative.
#
# **If I also run the [100] uniaxial patch** (Ξ_u / validation channel, separate from π44):
# under [100] the transverse plane goes anisotropic, m_{t,x} ≠ m_{t,z} → need both
# perpendicular cuts, not one.
#
# **Table vs science — don't confuse them.** To make shear/uni m_l *read* equal in the
# validation table, match the estimator: give shear its own 30-pt dense longitudinal leg
# (hw=5) through the relocated k0, don't widen the patch. Both read ~0.971, patch stays
# lean for M. Don't spend SCF budget widening the patch to ±2h for a cosmetic number.
#
# **Sanity to keep:** read band 5 (first occ-0, CBM ~6.4 eV), not the whole spectrum.
# Line-mode locates the true Δ-minimum; the mesh misses it.
#
# **Next session:** wrap the 2D Newton relocation as one function → run it at ε=0 as the
# reduction check → sweep the shear strains with frozen h → m_xy(ε) → slope = dm_xy/dε →
# feed the mass-door π44 estimate.
